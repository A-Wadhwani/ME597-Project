# %%
# import the libraries
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import tensorflow as tf
import pandas as pd
from datetime import datetime
from sklearn.metrics import r2_score
print("TensorFlow version: ",tf.__version__)  #print the version of tensorflow
# Out:
# TensorFlow version:  2.3.0

# %%
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

# %%
#Helper Functions
def get_weekday2(year, month, day):
    dates = pd.DataFrame()
    dates['y'] = year
    dates['m'] = month
    dates['d'] = day
    dates['dates'] = dates['y'].astype('str') + '-' + dates['m'].astype('str') + '-' + dates['d'].astype('str')
    return get_weekday(dates['dates'])

#Get day of week based on date
def get_weekday(dates):
    return [1 if (datetime.strptime(d,"%Y-%m-%d").weekday() >= 5) else 0 for d in dates]

# %% [markdown]
# # Exploratory Data Analysis

# %%
data = pd.read_csv('https://raw.githubusercontent.com/A-Wadhwani/ME597-Project/main/Datasets/Combined_PowerWeatherData2.csv')
copy = data
data
# Out:
#        Year  Month  ...  Square Feet       Type
# 0      2016      8  ...       113866  Classroom
# 1      2016      8  ...       113866  Classroom
# 2      2016      8  ...       113866  Classroom
# 3      2016      8  ...       113866  Classroom
# 4      2016      8  ...       113866  Classroom
# ...     ...    ...  ...          ...        ...
# 24241  2019     12  ...        35000  Classroom
# 24242  2019     12  ...        35000  Classroom
# 24243  2019     12  ...        35000  Classroom
# 24244  2019     12  ...        35000  Classroom
# 24245  2019     12  ...        35000  Classroom
#
# [24246 rows x 20 columns]

# %%
data.describe()
# Out:
#                Year         Month  ...       Weekday    Square Feet
# count  24246.000000  24246.000000  ...  24246.000000   24246.000000
# mean    2018.192609      6.748866  ...      0.285820   99425.628392
# std        1.038832      3.410584  ...      0.451814   27215.621821
# min     2016.000000      1.000000  ...      0.000000   35000.000000
# 25%     2017.000000      4.000000  ...      0.000000   81600.000000
# 50%     2019.000000      7.000000  ...      0.000000  105775.000000
# 75%     2019.000000     10.000000  ...      1.000000  121074.000000
# max     2019.000000     12.000000  ...      1.000000  141000.000000
#
# [8 rows x 17 columns]

# %%
#Creating column to denote each building type
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
data['Type'] = encoder.fit_transform(np.reshape(data['Type'].values, (-1,1)))
data['Type'].describe()
# Out:
# count    24246.000000
# mean         0.517570
# std          0.499702
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: Type, dtype: float64

# %%
encoder.inverse_transform(np.reshape([0, 1], (-1,1)))
# Out:
# array([['Classroom'],
#        ['Laboratory']], dtype=object)

# %%
#Removing unnecessary columns
data = data.drop(['University Name', 'Building Name'], axis=1)
data.head()
# Out:
#    Year  Month  Day    DNI Mean  ...  Power Consumption  Weekday  Square Feet  Type
# 0  2016      8   10  310.769231  ...        5289.221903        0       113866   0.0
# 1  2016      8   11  458.363636  ...        6232.404214        0       113866   0.0
# 2  2016      8   12  419.000000  ...        6484.952963        0       113866   0.0
# 3  2016      8   13  498.666667  ...        6098.378307        1       113866   0.0
# 4  2016      8   14   47.666667  ...        6235.404728        1       113866   0.0
#
# [5 rows x 18 columns]

# %%
#Select one building's data
view = data[data['Square Feet'] == 113866]
#See graphs for data vs Power Consumption
sns.pairplot(view, x_vars = ['Power Consumption', 'DNI Mean', 'Precipitable Water', 'Relative Humidity', 'Temperature', 'Pressure', 'Wind Speed'], y_vars=['Power Consumption'])
plt.show()

# %%
#Splitting into X and Y
X = data.drop(["Power Consumption", "Wind Direction"],axis=1) 
y = data["Power Consumption"]

# %%
y = np.reshape(y.values, (-1,1))

# %%
# scaling inputs using StandardScaler
from sklearn.preprocessing import StandardScaler
x_scaler = StandardScaler() 
y_scaler = StandardScaler()

x_f = x_scaler.fit_transform(X)
y_f = y_scaler.fit_transform(y)  

x_f = pd.DataFrame(x_f)

# %%
x_f
# Out:
#              0         1         2   ...        13        14       15
# 0     -2.110692  0.366846 -0.652989  ... -0.632620  0.530602 -1.03578
# 1     -2.110692  0.366846 -0.539349  ... -0.632620  0.530602 -1.03578
# 2     -2.110692  0.366846 -0.425710  ... -0.632620  0.530602 -1.03578
# 3     -2.110692  0.366846 -0.312070  ...  1.580728  0.530602 -1.03578
# 4     -2.110692  0.366846 -0.198431  ...  1.580728  0.530602 -1.03578
# ...         ...       ...       ...  ...       ...       ...      ...
# 24241  0.777226  1.539690  1.278882  ... -0.632620 -2.367279 -1.03578
# 24242  0.777226  1.539690  1.392521  ...  1.580728 -2.367279 -1.03578
# 24243  0.777226  1.539690  1.506161  ...  1.580728 -2.367279 -1.03578
# 24244  0.777226  1.539690  1.619800  ... -0.632620 -2.367279 -1.03578
# 24245  0.777226  1.539690  1.733440  ... -0.632620 -2.367279 -1.03578
#
# [24246 rows x 16 columns]

# %%
x_f = x_f.values

# %%
x_f.dtype
# Out:
# dtype('float64')

# %%
# split the data into train and test sets
from sklearn.model_selection import train_test_split  
x_f_train, x_f_test, y_f_train, y_f_test = train_test_split(x_f,y_f, test_size = 0.2, shuffle=True)

# %%
# print the number of training and test damples
print("Number of training samples: ",len(x_f_train))
print("Number of testing samples: ",len(x_f_test))
# Out:
# Number of training samples:  19396
# Number of testing samples:  4850

# %% [markdown]
# # Building the Model

# %%
model = Sequential()

model.add(Dense(512, input_shape=(16, ), activation='relu', name='dense_1'))
model.add(Dense(256, activation='relu', name='dense_3'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu', name='dense_4'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu', name='dense_5'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu', name='dense_6'))
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu', name='dense_7'))
model.add(Dense(1, activation='linear', name='dense_output'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               8704
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_output (Dense)         (None, 1)                 17
# =================================================================
# Total params: 183,809
# Trainable params: 183,809
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = keras.optimizers.Adam(learning_rate = 0.001)
model.compile(loss='mse', optimizer=opt, metrics=['mse', 'mae'])

#Tensorboard tool callback
log_dir = "logs\\fit3\\" + datetime.now().strftime("%M")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 100000000)

#Reduce Learning rate on Plateau 
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=10, verbose = 1)

#Earlystopping callback
early_stop = EarlyStopping(monitor ='val_loss', min_delta= 1e-3, patience = 50, verbose = 1, restore_best_weights=True)

history = model.fit(x_f_train, y_f_train, callbacks = [tensorboard_callback, early_stop, reduce_lr], 
                    validation_data=(x_f_test, y_f_test), epochs=400, batch_size=90, verbose=1)
# Out:
# Epoch 1/400
# 216/216 [==============================] - 1s 5ms/step - loss: 0.5721 - mse: 0.5721 - mae: 0.5818 - val_loss: 0.4721 - val_mse: 0.4721 - val_mae: 0.5690
# Epoch 2/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.4343 - mse: 0.4343 - mae: 0.4999 - val_loss: 0.4369 - val_mse: 0.4369 - val_mae: 0.5458
# Epoch 3/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.3927 - mse: 0.3927 - mae: 0.4734 - val_loss: 0.4416 - val_mse: 0.4416 - val_mae: 0.5171
# Epoch 4/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.3634 - mse: 0.3634 - mae: 0.4542 - val_loss: 0.3981 - val_mse: 0.3981 - val_mae: 0.5082
# Epoch 5/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.3394 - mse: 0.3394 - mae: 0.4324 - val_loss: 0.4058 - val_mse: 0.4058 - val_mae: 0.5326
# Epoch 6/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.3115 - mse: 0.3115 - mae: 0.4076 - val_loss: 0.3449 - val_mse: 0.3449 - val_mae: 0.4564
# Epoch 7/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2643 - mse: 0.2643 - mae: 0.3590 - val_loss: 0.3058 - val_mse: 0.3058 - val_mae: 0.4135
# Epoch 8/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2604 - mse: 0.2604 - mae: 0.3475 - val_loss: 0.2830 - val_mse: 0.2830 - val_mae: 0.4004
# Epoch 9/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2404 - mse: 0.2404 - mae: 0.3280 - val_loss: 0.2938 - val_mse: 0.2938 - val_mae: 0.4074
# Epoch 10/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2339 - mse: 0.2339 - mae: 0.3215 - val_loss: 0.2732 - val_mse: 0.2732 - val_mae: 0.3855
# Epoch 11/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2270 - mse: 0.2270 - mae: 0.3139 - val_loss: 0.2497 - val_mse: 0.2497 - val_mae: 0.3582
# Epoch 12/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2358 - mse: 0.2358 - mae: 0.3153 - val_loss: 0.2512 - val_mse: 0.2512 - val_mae: 0.3602
# Epoch 13/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2298 - mse: 0.2298 - mae: 0.3105 - val_loss: 0.2369 - val_mse: 0.2369 - val_mae: 0.3424
# Epoch 14/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2178 - mse: 0.2178 - mae: 0.3017 - val_loss: 0.2425 - val_mse: 0.2425 - val_mae: 0.3486
# Epoch 15/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2079 - mse: 0.2079 - mae: 0.2941 - val_loss: 0.2353 - val_mse: 0.2353 - val_mae: 0.3477
# Epoch 16/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2047 - mse: 0.2047 - mae: 0.2896 - val_loss: 0.2200 - val_mse: 0.2200 - val_mae: 0.3298
# Epoch 17/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2042 - mse: 0.2042 - mae: 0.2888 - val_loss: 0.2340 - val_mse: 0.2340 - val_mae: 0.3305
# Epoch 18/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2064 - mse: 0.2064 - mae: 0.2914 - val_loss: 0.1989 - val_mse: 0.1989 - val_mae: 0.3074
# Epoch 19/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.2110 - mse: 0.2110 - mae: 0.2932 - val_loss: 0.2114 - val_mse: 0.2114 - val_mae: 0.3259
# Epoch 20/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1871 - mse: 0.1871 - mae: 0.2768 - val_loss: 0.2012 - val_mse: 0.2012 - val_mae: 0.3096
# Epoch 21/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1851 - mse: 0.1851 - mae: 0.2747 - val_loss: 0.2072 - val_mse: 0.2072 - val_mae: 0.3228
# Epoch 22/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1818 - mse: 0.1818 - mae: 0.2693 - val_loss: 0.1817 - val_mse: 0.1817 - val_mae: 0.2921
# Epoch 23/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1881 - mse: 0.1881 - mae: 0.2748 - val_loss: 0.1910 - val_mse: 0.1910 - val_mae: 0.2980
# Epoch 24/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1946 - mse: 0.1946 - mae: 0.2760 - val_loss: 0.2306 - val_mse: 0.2306 - val_mae: 0.3126
# Epoch 25/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1870 - mse: 0.1870 - mae: 0.2743 - val_loss: 0.1770 - val_mse: 0.1770 - val_mae: 0.2849
# Epoch 26/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1672 - mse: 0.1672 - mae: 0.2563 - val_loss: 0.1833 - val_mse: 0.1833 - val_mae: 0.2914
# Epoch 27/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1811 - mse: 0.1811 - mae: 0.2645 - val_loss: 0.2127 - val_mse: 0.2127 - val_mae: 0.3145
# Epoch 28/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1830 - mse: 0.1830 - mae: 0.2679 - val_loss: 0.1754 - val_mse: 0.1754 - val_mae: 0.2823
# Epoch 29/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1692 - mse: 0.1692 - mae: 0.2555 - val_loss: 0.1688 - val_mse: 0.1688 - val_mae: 0.2707
# Epoch 30/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1706 - mse: 0.1706 - mae: 0.2550 - val_loss: 0.2031 - val_mse: 0.2031 - val_mae: 0.3176
# Epoch 31/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1613 - mse: 0.1613 - mae: 0.2497 - val_loss: 0.1938 - val_mse: 0.1938 - val_mae: 0.3022
# Epoch 32/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1667 - mse: 0.1667 - mae: 0.2538 - val_loss: 0.1742 - val_mse: 0.1742 - val_mae: 0.2755
# Epoch 33/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1614 - mse: 0.1614 - mae: 0.2488 - val_loss: 0.1817 - val_mse: 0.1817 - val_mae: 0.2856
# Epoch 34/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1586 - mse: 0.1586 - mae: 0.2445 - val_loss: 0.1744 - val_mse: 0.1744 - val_mae: 0.2787
# Epoch 35/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1715 - mse: 0.1715 - mae: 0.2527 - val_loss: 0.2131 - val_mse: 0.2131 - val_mae: 0.3080
# Epoch 36/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1732 - mse: 0.1732 - mae: 0.2583 - val_loss: 0.1850 - val_mse: 0.1850 - val_mae: 0.2926
# Epoch 37/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1729 - mse: 0.1729 - mae: 0.2567 - val_loss: 0.2046 - val_mse: 0.2046 - val_mae: 0.3117
# Epoch 38/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1673 - mse: 0.1673 - mae: 0.2530 - val_loss: 0.1755 - val_mse: 0.1755 - val_mae: 0.2839
# Epoch 39/400
# 213/216 [============================>.] - ETA: 0s - loss: 0.1544 - mse: 0.1544 - mae: 0.2417
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1544 - mse: 0.1544 - mae: 0.2420 - val_loss: 0.1799 - val_mse: 0.1799 - val_mae: 0.2868
# Epoch 40/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1498 - mse: 0.1498 - mae: 0.2351 - val_loss: 0.1649 - val_mse: 0.1649 - val_mae: 0.2658
# Epoch 41/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1469 - mse: 0.1469 - mae: 0.2320 - val_loss: 0.1675 - val_mse: 0.1675 - val_mae: 0.2687
# Epoch 42/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1462 - mse: 0.1462 - mae: 0.2312 - val_loss: 0.1671 - val_mse: 0.1671 - val_mae: 0.2674
# Epoch 43/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1444 - mse: 0.1444 - mae: 0.2297 - val_loss: 0.1643 - val_mse: 0.1643 - val_mae: 0.2635
# Epoch 44/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1430 - mse: 0.1430 - mae: 0.2282 - val_loss: 0.1653 - val_mse: 0.1653 - val_mae: 0.2654
# Epoch 45/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1424 - mse: 0.1424 - mae: 0.2278 - val_loss: 0.1675 - val_mse: 0.1675 - val_mae: 0.2677
# Epoch 46/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1430 - mse: 0.1430 - mae: 0.2275 - val_loss: 0.1654 - val_mse: 0.1654 - val_mae: 0.2647
# Epoch 47/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1407 - mse: 0.1407 - mae: 0.2259 - val_loss: 0.1603 - val_mse: 0.1603 - val_mae: 0.2585
# Epoch 48/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1407 - mse: 0.1407 - mae: 0.2239 - val_loss: 0.1590 - val_mse: 0.1590 - val_mae: 0.2568
# Epoch 49/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1381 - mse: 0.1381 - mae: 0.2226 - val_loss: 0.1635 - val_mse: 0.1635 - val_mae: 0.2626
# Epoch 50/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1392 - mse: 0.1392 - mae: 0.2226 - val_loss: 0.1683 - val_mse: 0.1683 - val_mae: 0.2681
# Epoch 51/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1378 - mse: 0.1378 - mae: 0.2204 - val_loss: 0.1596 - val_mse: 0.1596 - val_mae: 0.2598
# Epoch 52/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1358 - mse: 0.1358 - mae: 0.2192 - val_loss: 0.1604 - val_mse: 0.1604 - val_mae: 0.2615
# Epoch 53/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1356 - mse: 0.1356 - mae: 0.2183 - val_loss: 0.1593 - val_mse: 0.1593 - val_mae: 0.2562
# Epoch 54/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1337 - mse: 0.1337 - mae: 0.2171 - val_loss: 0.1574 - val_mse: 0.1574 - val_mae: 0.2573
# Epoch 55/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1318 - mse: 0.1318 - mae: 0.2157 - val_loss: 0.1547 - val_mse: 0.1547 - val_mae: 0.2533
# Epoch 56/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1311 - mse: 0.1311 - mae: 0.2136 - val_loss: 0.1596 - val_mse: 0.1596 - val_mae: 0.2566
# Epoch 57/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1314 - mse: 0.1314 - mae: 0.2138 - val_loss: 0.1563 - val_mse: 0.1563 - val_mae: 0.2539
# Epoch 58/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1292 - mse: 0.1292 - mae: 0.2116 - val_loss: 0.1543 - val_mse: 0.1543 - val_mae: 0.2517
# Epoch 59/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1292 - mse: 0.1292 - mae: 0.2115 - val_loss: 0.1547 - val_mse: 0.1547 - val_mae: 0.2533
# Epoch 60/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1294 - mse: 0.1294 - mae: 0.2106 - val_loss: 0.1539 - val_mse: 0.1539 - val_mae: 0.2530
# Epoch 61/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1262 - mse: 0.1262 - mae: 0.2077 - val_loss: 0.1521 - val_mse: 0.1521 - val_mae: 0.2508
# Epoch 62/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1238 - mse: 0.1238 - mae: 0.2064 - val_loss: 0.1521 - val_mse: 0.1521 - val_mae: 0.2501
# Epoch 63/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1252 - mse: 0.1252 - mae: 0.2067 - val_loss: 0.1530 - val_mse: 0.1530 - val_mae: 0.2496
# Epoch 64/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1256 - mse: 0.1256 - mae: 0.2075 - val_loss: 0.1552 - val_mse: 0.1552 - val_mae: 0.2527
# Epoch 65/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1261 - mse: 0.1261 - mae: 0.2065 - val_loss: 0.1539 - val_mse: 0.1539 - val_mae: 0.2495
# Epoch 66/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1221 - mse: 0.1221 - mae: 0.2027 - val_loss: 0.1527 - val_mse: 0.1527 - val_mae: 0.2468
# Epoch 67/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1233 - mse: 0.1233 - mae: 0.2036 - val_loss: 0.1534 - val_mse: 0.1534 - val_mae: 0.2473
# Epoch 68/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1233 - mse: 0.1233 - mae: 0.2039 - val_loss: 0.1486 - val_mse: 0.1486 - val_mae: 0.2428
# Epoch 69/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1231 - mse: 0.1231 - mae: 0.2035 - val_loss: 0.1486 - val_mse: 0.1486 - val_mae: 0.2426
# Epoch 70/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1231 - mse: 0.1231 - mae: 0.2027 - val_loss: 0.1479 - val_mse: 0.1479 - val_mae: 0.2406
# Epoch 71/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1211 - mse: 0.1211 - mae: 0.2009 - val_loss: 0.1536 - val_mse: 0.1536 - val_mae: 0.2466
# Epoch 72/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1224 - mse: 0.1224 - mae: 0.2023 - val_loss: 0.1473 - val_mse: 0.1473 - val_mae: 0.2395
# Epoch 73/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1213 - mse: 0.1213 - mae: 0.1992 - val_loss: 0.1511 - val_mse: 0.1511 - val_mae: 0.2460
# Epoch 74/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1199 - mse: 0.1199 - mae: 0.2009 - val_loss: 0.1485 - val_mse: 0.1485 - val_mae: 0.2394
# Epoch 75/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1211 - mse: 0.1211 - mae: 0.2006 - val_loss: 0.1575 - val_mse: 0.1575 - val_mae: 0.2466
# Epoch 76/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1201 - mse: 0.1201 - mae: 0.1992 - val_loss: 0.1517 - val_mse: 0.1517 - val_mae: 0.2432
# Epoch 77/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1211 - mse: 0.1211 - mae: 0.1990 - val_loss: 0.1499 - val_mse: 0.1499 - val_mae: 0.2410
# Epoch 78/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1197 - mse: 0.1197 - mae: 0.1977 - val_loss: 0.1473 - val_mse: 0.1473 - val_mae: 0.2379
# Epoch 79/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1194 - mse: 0.1194 - mae: 0.1970 - val_loss: 0.1480 - val_mse: 0.1480 - val_mae: 0.2398
# Epoch 80/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1179 - mse: 0.1179 - mae: 0.1962 - val_loss: 0.1516 - val_mse: 0.1516 - val_mae: 0.2449
# Epoch 81/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1166 - mse: 0.1166 - mae: 0.1956 - val_loss: 0.1475 - val_mse: 0.1475 - val_mae: 0.2361
# Epoch 82/400
# 216/216 [==============================] - ETA: 0s - loss: 0.1177 - mse: 0.1177 - mae: 0.1953
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1177 - mse: 0.1177 - mae: 0.1953 - val_loss: 0.1516 - val_mse: 0.1516 - val_mae: 0.2402
# Epoch 83/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1152 - mse: 0.1152 - mae: 0.1926 - val_loss: 0.1489 - val_mse: 0.1489 - val_mae: 0.2382
# Epoch 84/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1161 - mse: 0.1161 - mae: 0.1926 - val_loss: 0.1508 - val_mse: 0.1508 - val_mae: 0.2410
# Epoch 85/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1157 - mse: 0.1157 - mae: 0.1926 - val_loss: 0.1491 - val_mse: 0.1491 - val_mae: 0.2376
# Epoch 86/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1152 - mse: 0.1152 - mae: 0.1915 - val_loss: 0.1506 - val_mse: 0.1506 - val_mae: 0.2405
# Epoch 87/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1142 - mse: 0.1142 - mae: 0.1913 - val_loss: 0.1492 - val_mse: 0.1492 - val_mae: 0.2383
# Epoch 88/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1152 - mse: 0.1152 - mae: 0.1931 - val_loss: 0.1496 - val_mse: 0.1496 - val_mae: 0.2384
# Epoch 89/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1151 - mse: 0.1151 - mae: 0.1925 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2379
# Epoch 90/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1162 - mse: 0.1162 - mae: 0.1913 - val_loss: 0.1500 - val_mse: 0.1500 - val_mae: 0.2401
# Epoch 91/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1134 - mse: 0.1134 - mae: 0.1910 - val_loss: 0.1512 - val_mse: 0.1512 - val_mae: 0.2409
# Epoch 92/400
# 213/216 [============================>.] - ETA: 0s - loss: 0.1148 - mse: 0.1148 - mae: 0.1905
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1143 - mse: 0.1143 - mae: 0.1903 - val_loss: 0.1495 - val_mse: 0.1495 - val_mae: 0.2389
# Epoch 93/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1140 - mse: 0.1140 - mae: 0.1913 - val_loss: 0.1486 - val_mse: 0.1486 - val_mae: 0.2379
# Epoch 94/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1135 - mse: 0.1135 - mae: 0.1910 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 95/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1147 - mse: 0.1147 - mae: 0.1911 - val_loss: 0.1493 - val_mse: 0.1493 - val_mae: 0.2389
# Epoch 96/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1140 - mse: 0.1140 - mae: 0.1908 - val_loss: 0.1485 - val_mse: 0.1485 - val_mae: 0.2377
# Epoch 97/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1148 - mse: 0.1148 - mae: 0.1910 - val_loss: 0.1485 - val_mse: 0.1485 - val_mae: 0.2376
# Epoch 98/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1132 - mse: 0.1132 - mae: 0.1906 - val_loss: 0.1482 - val_mse: 0.1482 - val_mae: 0.2372
# Epoch 99/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1139 - mse: 0.1139 - mae: 0.1917 - val_loss: 0.1491 - val_mse: 0.1491 - val_mae: 0.2384
# Epoch 100/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1145 - mse: 0.1145 - mae: 0.1905 - val_loss: 0.1489 - val_mse: 0.1489 - val_mae: 0.2383
# Epoch 101/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1137 - mse: 0.1137 - mae: 0.1906 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2385
# Epoch 102/400
# 211/216 [============================>.] - ETA: 0s - loss: 0.1143 - mse: 0.1143 - mae: 0.1909
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1137 - mse: 0.1137 - mae: 0.1905 - val_loss: 0.1489 - val_mse: 0.1489 - val_mae: 0.2381
# Epoch 103/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1137 - mse: 0.1137 - mae: 0.1898 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 104/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1136 - mse: 0.1136 - mae: 0.1906 - val_loss: 0.1484 - val_mse: 0.1484 - val_mae: 0.2374
# Epoch 105/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1142 - mse: 0.1142 - mae: 0.1911 - val_loss: 0.1488 - val_mse: 0.1488 - val_mae: 0.2379
# Epoch 106/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1143 - mse: 0.1143 - mae: 0.1909 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 107/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1139 - mse: 0.1139 - mae: 0.1902 - val_loss: 0.1488 - val_mse: 0.1488 - val_mae: 0.2381
# Epoch 108/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1128 - mse: 0.1128 - mae: 0.1897 - val_loss: 0.1487 - val_mse: 0.1487 - val_mae: 0.2379
# Epoch 109/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1126 - mse: 0.1126 - mae: 0.1896 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 110/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1138 - mse: 0.1138 - mae: 0.1905 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 111/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1148 - mse: 0.1148 - mae: 0.1909 - val_loss: 0.1491 - val_mse: 0.1491 - val_mae: 0.2384
# Epoch 112/400
# 211/216 [============================>.] - ETA: 0s - loss: 0.1132 - mse: 0.1132 - mae: 0.1905
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1126 - mse: 0.1126 - mae: 0.1902 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 113/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1140 - mse: 0.1140 - mae: 0.1906 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 114/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1146 - mse: 0.1146 - mae: 0.1907 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 115/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1129 - mse: 0.1129 - mae: 0.1904 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 116/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1131 - mse: 0.1131 - mae: 0.1896 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 117/400
# 216/216 [==============================] - 1s 5ms/step - loss: 0.1135 - mse: 0.1135 - mae: 0.1906 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 118/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1130 - mse: 0.1130 - mae: 0.1904 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 119/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1128 - mse: 0.1128 - mae: 0.1898 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2383
# Epoch 120/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1132 - mse: 0.1132 - mae: 0.1896 - val_loss: 0.1489 - val_mse: 0.1489 - val_mae: 0.2381
# Epoch 121/400
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1138 - mse: 0.1138 - mae: 0.1901 - val_loss: 0.1489 - val_mse: 0.1489 - val_mae: 0.2381
# Epoch 122/400
# 212/216 [============================>.] - ETA: 0s - loss: 0.1126 - mse: 0.1126 - mae: 0.1900Restoring model weights from the end of the best epoch.
#
# Epoch 00122: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 216/216 [==============================] - 1s 4ms/step - loss: 0.1126 - mse: 0.1126 - mae: 0.1901 - val_loss: 0.1490 - val_mse: 0.1490 - val_mae: 0.2382
# Epoch 00122: early stopping

# %% [markdown]
# # Testing accuracy of Model with validation data

# %%
y_f_result = model.predict(x_f_test)
y_result = y_scaler.inverse_transform(y_f_result)
y_actual = y_scaler.inverse_transform(y_f_test)

compare = pd.DataFrame()
compare['Expected'] = y_actual.reshape(1,-1)[0]
compare['Result'] = y_result.reshape(1,-1)[0]
compare['Difference'] = compare['Expected'] - compare['Result']
compare['Percentage Error'] =  abs(100 * compare['Difference']/compare['Expected'])

#Print out percentile descriptions of model accuracy
compare['Percentage Error'].describe(percentiles=[0.1, 0.25, 0.50, 0.75, 0.90])
# Out:
# count    4850.000000
# mean       61.838390
# std       162.286152
# min         0.009536
# 10%         1.967639
# 25%         5.121473
# 50%        12.089468
# 75%        29.954304
# 90%       146.114441
# max      2533.030382
# Name: Percentage Error, dtype: float64

# %%
plt.hist(compare['Percentage Error'])
plt.show()

# %% [markdown]
# As observed, there are a few outliers in the model, but most of the data lies close to its expected value.

# %%
r_score = r2_score(y_actual, y_result)
print("R^2 score: ", r_score)
# Out:
# R^2 score:  0.8521700907072417

# %%
plt.scatter(compare['Expected'], compare['Result'])
plt.plot(compare['Expected'], compare['Expected'], c='Red')
plt.show()

# %%
plt.plot(history.history['mse'],label='Training MSE')
plt.plot(history.history['val_mse'],label='Testing MSE')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# As observed above, we have a decently high $r^2$ score. An ideal model would achieve 1 as the $r^2$ score.

# %% [markdown]
# # Building Model Analysis

# %%
def clean_data(location, skiprows = 0):
    df_weather = pd.read_csv(location, skiprows=skiprows)
    df_weather = df_weather.drop(columns=['Hour', 'Minute'])
    df_weather = df_weather[df_weather.DNI != 0]

    #Take mean, max and min for each DNI in DataFrame and mean for everything else
    
    #Take mean, max and min for each DNI and Temperature in DataFrame and mean for everything else
    max_temp = df_weather.groupby(['Year', 'Month', 'Day']).max().reset_index()['Temperature']
    min_temp = df_weather.groupby(['Year', 'Month', 'Day']).min().reset_index()['Temperature']
    
    max_dni = df_weather.groupby(['Year', 'Month', 'Day']).max().reset_index()['DNI']
    min_dni = df_weather.groupby(['Year', 'Month', 'Day']).min().reset_index()['DNI']
    
    df_weather = pd.DataFrame(df_weather.groupby(['Year', 'Month', 'Day']).mean().reset_index())
    
    df_weather.insert(4, 'DNI Max', max_dni)
    df_weather.insert(5, 'DNI Min', min_dni)
    df_weather.insert(11, 'Temp Max', max_temp)
    df_weather.insert(12, 'Temp Min', min_temp)

    return df_weather

# %%
def training_prep(data, square_feet, building_type):
    data = data.loc[:, ['Year', 'Month', 'Day', 'DNI', 'DNI Max', 'DNI Min', 'Wind Speed', 'Precipitable Water', 'Wind Direction', 'Relative Humidity', 'Temperature', 'Temp Max', 'Temp Min', 'Pressure']]
    data.loc[:, 'Weekday'] = get_weekday2(data['Year'], data['Month'], data['Day'])
    data = data.drop(['Wind Direction'], axis=1)
    data.loc[:, 'Square Feet'] = square_feet
    data.loc[:, 'Type'] = building_type
    return data

# %%
X
# Out:
#        Year  Month  Day    DNI Mean  ...     Pressure  Weekday  Square Feet  Type
# 0      2016      8   10  310.769231  ...  1010.000000        0       113866   0.0
# 1      2016      8   11  458.363636  ...  1010.000000        0       113866   0.0
# 2      2016      8   12  419.000000  ...  1010.000000        0       113866   0.0
# 3      2016      8   13  498.666667  ...  1010.000000        1       113866   0.0
# 4      2016      8   14   47.666667  ...  1010.000000        1       113866   0.0
# ...     ...    ...  ...         ...  ...          ...      ...          ...   ...
# 24241  2019     12   27  601.050000  ...   998.650000        0        35000   0.0
# 24242  2019     12   28  661.400000  ...  1001.100000        1        35000   0.0
# 24243  2019     12   29   38.428571  ...   999.214286        1        35000   0.0
# 24244  2019     12   30  666.350000  ...  1000.200000        0        35000   0.0
# 24245  2019     12   31  478.100000  ...  1000.950000        0        35000   0.0
#
# [24246 rows x 16 columns]

# %%
#Taking data for University of Michigan Research Building
michigan_data = training_prep(clean_data('https://raw.githubusercontent.com/A-Wadhwani/ME597-Project/main/Datasets/AnnArbor_Weather.csv'), 100000, 1)
michigan_data.head()
# Out:
#    Year  Month  Day         DNI  ...     Pressure  Weekday  Square Feet  Type
# 0  2019      1    1   52.111111  ...   993.888889        0       100000     1
# 1  2019      1    2  396.000000  ...  1011.400000        0       100000     1
# 2  2019      1    3  299.700000  ...   997.400000        0       100000     1
# 3  2019      1    4  281.900000  ...   997.300000        0       100000     1
# 4  2019      1    5   10.000000  ...   986.000000        1       100000     1
#
# [5 rows x 16 columns]

# %%
#Applying transform to data
mi_test = x_scaler.transform(michigan_data)

# %%
#Testing model:
mi_result = y_scaler.inverse_transform(model.predict(mi_test))
compare = pd.DataFrame()
compare['Month'] = michigan_data['Month']
compare['Result'] = mi_result.reshape(1,-1)[0]
compare.head()
# Out:
#    Month       Result
# 0      1  7894.780762
# 1      1  8042.916992
# 2      1  7921.888672
# 3      1  7911.225098
# 4      1  7873.444824

# %%
compare = pd.DataFrame(compare.groupby(['Month']).sum().reset_index())
actual = [212259, 240083, 218423, 233777, 240106, 272017, 300123, 295701, 288447, 254802, 228097, 220258]
compare['Actual'] = actual
compare['Difference'] = compare['Actual'] - compare['Result']
compare['Percentage Error'] = 100 * compare['Difference']/compare['Actual']
compare['Percentage Error'] = abs(compare['Percentage Error'])
compare.head(12)
# Out:
#     Month         Result  Actual    Difference  Percentage Error
# 0       1  239626.093750  212259 -27367.093750         12.893255
# 1       2  217601.343750  240083  22481.656250          9.364118
# 2       3  240168.781250  218423 -21745.781250          9.955811
# 3       4  234403.734375  233777   -626.734375          0.268091
# 4       5  242153.718750  240106  -2047.718750          0.852839
# 5       6  230573.562500  272017  41443.437500         15.235606
# 6       7  222455.687500  300123  77667.312500         25.878494
# 7       8  230154.046875  295701  65546.953125         22.166632
# 8       9  218224.609375  288447  70222.390625         24.344989
# 9      10  234458.437500  254802  20343.562500          7.984067
# 10     11  225521.890625  228097   2575.109375          1.128954
# 11     12  220963.984375  220258   -705.984375          0.320526

# %%
compare.describe()
# Out:
#            Month         Result         Actual    Difference  Percentage Error
# count  12.000000      12.000000      12.000000     12.000000         12.000000
# mean    6.500000  229692.171875  250341.083333  20648.925781         10.866115
# std     3.605551    8703.556641   31378.512646  35692.700166          9.477012
# min     1.000000  217601.343750  212259.000000 -27367.093750          0.268091
# 25%     3.750000  222082.761719  226137.250000  -1041.417969          1.059925
# 50%     6.500000  230363.804688  240094.500000  11459.335938          9.659965
# 75%     9.250000  235750.351562  276124.500000  47469.316406         16.968362
# max    12.000000  242153.718750  300123.000000  77667.312500         25.878494

# %% [markdown]
# As observed here, the estimated values seem to be close to the real values. The mean percentage error is about 11%.

# %%
from joblib import dump, load
dump(x_scaler, 'x_scaler.bin', compress=True)
dump(y_scaler, 'y_scaler.bin', compress=True)
model.save('uni_model.h5')
