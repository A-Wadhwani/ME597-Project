# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Wadhwani/ME597-Project/blob/main/Power_gen1_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_csv('Datasets/Solar Power/Plant_1_Generation_Data.csv')
data=pd.DataFrame(data)
data.head(20)
# Out:
#            DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0   15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1   15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2   15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3   15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4   15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# 5   15-05-2020 00:00   4135001  VHMLBKoKgIrUVDU       0.0       0.0
# 6   15-05-2020 00:00   4135001  WRmjgnKYAwPKWDb       0.0       0.0
# 7   15-05-2020 00:00   4135001  ZnxXDlPa8U1GXgE       0.0       0.0
# 8   15-05-2020 00:00   4135001  ZoEaEvLYb1n2sOq       0.0       0.0
# 9   15-05-2020 00:00   4135001  adLQvlD726eNBSB       0.0       0.0
# 10  15-05-2020 00:00   4135001  bvBOhCH3iADSZry       0.0       0.0
# 11  15-05-2020 00:00   4135001  iCRJl6heRkivqQ3       0.0       0.0
# 12  15-05-2020 00:00   4135001  ih0vzX44oOqAx2f       0.0       0.0
# ...

# %%
data.dtypes
# Out:
# DATE_TIME       object
# PLANT_ID         int64
# SOURCE_KEY      object
# DC_POWER       float64
# AC_POWER       float64
# DAILY_YIELD    float64
# TOTAL_YIELD    float64
# dtype: object

# %%
data['DATE'] = pd.to_datetime(data['DATE_TIME']).dt.date
data['TIME'] = pd.to_datetime(data['DATE_TIME']).dt.time

# %%
data.head(3881)
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0     15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1     15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2     15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3     15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4     15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
# ...                ...       ...              ...       ...       ...
# 3876  16-05-2020 23:45   4135001  adLQvlD726eNBSB       0.0       0.0
# 3877  16-05-2020 23:45   4135001  bvBOhCH3iADSZry       0.0       0.0
# 3878  16-05-2020 23:45   4135001  iCRJl6heRkivqQ3       0.0       0.0
# 3879  16-05-2020 23:45   4135001  ih0vzX44oOqAx2f       0.0       0.0
# 3880  16-05-2020 23:45   4135001  pkci93gMrogZuBj       0.0       0.0
#
#       DAILY_YIELD  TOTAL_YIELD        DATE      TIME
# 0             0.0    6259559.0  2020-05-15  00:00:00
# ...

# %%
data2 = data[data['TIME'].astype(str) == '23:45:00']
data2.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 3866  16-05-2020 23:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 3867  16-05-2020 23:45   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 3868  16-05-2020 23:45   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3869  16-05-2020 23:45   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 3870  16-05-2020 23:45   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#       DAILY_YIELD  TOTAL_YIELD        DATE      TIME
# 3866  6292.000000    6271605.0  2020-05-16  23:45:00
# 3867  5768.000000    6196594.0  2020-05-16  23:45:00
# 3868  6656.000000    7000689.0  2020-05-16  23:45:00
# 3869  6461.000000    7615537.0  2020-05-16  23:45:00
# 3870  4704.285714    7172021.0  2020-05-16  23:45:00
